# %%
import pandas as pd

file = pd.read_csv("phys_dataset.csv", encoding='ISO-8859-1')
# Out:
# /tmp/ipykernel_233145/1342731075.py:3: DtypeWarning: Columns (11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   file = pd.read_csv("phys_dataset.csv", encoding = 'ISO-8859-1')

# %%
file.columns
# Out:
# Index(['Rndrng_NPI', 'Rndrng_Prvdr_Last_Org_Name', 'Rndrng_Prvdr_First_Name',
#        'Rndrng_Prvdr_MI', 'Rndrng_Prvdr_Crdntls', 'Rndrng_Prvdr_Gndr',
#        'Rndrng_Prvdr_Ent_Cd', 'Rndrng_Prvdr_St1', 'Rndrng_Prvdr_St2',
#        'Rndrng_Prvdr_City', 'Rndrng_Prvdr_State_Abrvtn',
#        'Rndrng_Prvdr_State_FIPS', 'Rndrng_Prvdr_Zip5', 'Rndrng_Prvdr_RUCA',
#        'Rndrng_Prvdr_RUCA_Desc', 'Rndrng_Prvdr_Cntry', 'Rndrng_Prvdr_Type',
#        'Rndrng_Prvdr_Mdcr_Prtcptg_Ind', 'Tot_HCPCS_Cds', 'Tot_Benes',
#        'Tot_Srvcs', 'Tot_Sbmtd_Chrg', 'Tot_Mdcr_Alowd_Amt',
#        'Tot_Mdcr_Pymt_Amt', 'Tot_Mdcr_Stdzd_Amt', 'Drug_Sprsn_Ind',
#        'Drug_Tot_HCPCS_Cds', 'Drug_Tot_Benes', 'Drug_Tot_Srvcs',
#        'Drug_Sbmtd_Chrg', 'Drug_Mdcr_Alowd_Amt', 'Drug_Mdcr_Pymt_Amt',
#        'Drug_Mdcr_Stdzd_Amt', 'Med_Sprsn_Ind', 'Med_Tot_HCPCS_Cds',
#        'Med_Tot_Benes', 'Med_Tot_Srvcs', 'Med_Sbmtd_Chrg',
#        'Med_Mdcr_Alowd_Amt', 'Med_Mdcr_Pymt_Amt', 'Med_Mdcr_Stdzd_Amt',
# ...

# %%
cols = file.columns
phys_cols = [col for col in cols if "Rndrng_" in col]
payments_cols = [col for col in cols if ("Tot" in col or "Amt" in col)]
bene_cols = [col for col in cols if "Bene_" in col]

# %%
phys_cols
# Out:
# ['Rndrng_NPI',
#  'Rndrng_Prvdr_Last_Org_Name',
#  'Rndrng_Prvdr_First_Name',
#  'Rndrng_Prvdr_MI',
#  'Rndrng_Prvdr_Crdntls',
#  'Rndrng_Prvdr_Gndr',
#  'Rndrng_Prvdr_Ent_Cd',
#  'Rndrng_Prvdr_St1',
#  'Rndrng_Prvdr_St2',
#  'Rndrng_Prvdr_City',
#  'Rndrng_Prvdr_State_Abrvtn',
#  'Rndrng_Prvdr_State_FIPS',
#  'Rndrng_Prvdr_Zip5',
#  'Rndrng_Prvdr_RUCA',
#  'Rndrng_Prvdr_RUCA_Desc',
#  'Rndrng_Prvdr_Cntry',
#  'Rndrng_Prvdr_Type',
#  'Rndrng_Prvdr_Mdcr_Prtcptg_Ind']

# %%
bene_cols
# Out:
# ['Bene_Avg_Age',
#  'Bene_Age_LT_65_Cnt',
#  'Bene_Age_65_74_Cnt',
#  'Bene_Age_75_84_Cnt',
#  'Bene_Age_GT_84_Cnt',
#  'Bene_Feml_Cnt',
#  'Bene_Male_Cnt',
#  'Bene_Race_Wht_Cnt',
#  'Bene_Race_Black_Cnt',
#  'Bene_Race_API_Cnt',
#  'Bene_Race_Hspnc_Cnt',
#  'Bene_Race_NatInd_Cnt',
#  'Bene_Race_Othr_Cnt',
#  'Bene_Dual_Cnt',
#  'Bene_Ndual_Cnt',
#  'Bene_CC_AF_Pct',
#  'Bene_CC_Alzhmr_Pct',
#  'Bene_CC_Asthma_Pct',
#  'Bene_CC_Cncr_Pct',
#  'Bene_CC_CHF_Pct',
#  'Bene_CC_CKD_Pct',
#  'Bene_CC_COPD_Pct',
#  'Bene_CC_Dprssn_Pct',
#  'Bene_CC_Dbts_Pct',
#  'Bene_CC_Hyplpdma_Pct',
#  'Bene_CC_Hyprtnsn_Pct',
#  'Bene_CC_IHD_Pct',
#  'Bene_CC_Opo_Pct',
#  'Bene_CC_RAOA_Pct',
#  'Bene_CC_Sz_Pct',
#  'Bene_CC_Strok_Pct',
#  'Bene_Avg_Risk_Scre']

# %%
payments_cols
# Out:
# ['Tot_HCPCS_Cds',
#  'Tot_Benes',
#  'Tot_Srvcs',
#  'Tot_Sbmtd_Chrg',
#  'Tot_Mdcr_Alowd_Amt',
#  'Tot_Mdcr_Pymt_Amt',
#  'Tot_Mdcr_Stdzd_Amt',
#  'Drug_Tot_HCPCS_Cds',
#  'Drug_Tot_Benes',
#  'Drug_Tot_Srvcs',
#  'Drug_Mdcr_Alowd_Amt',
#  'Drug_Mdcr_Pymt_Amt',
#  'Drug_Mdcr_Stdzd_Amt',
#  'Med_Tot_HCPCS_Cds',
#  'Med_Tot_Benes',
#  'Med_Tot_Srvcs',
#  'Med_Mdcr_Alowd_Amt',
#  'Med_Mdcr_Pymt_Amt',
#  'Med_Mdcr_Stdzd_Amt']

# %%
file.describe()
# Out:
#          Rndrng_NPI  Rndrng_Prvdr_RUCA  Tot_HCPCS_Cds     Tot_Benes  \
# count  1.161542e+06       1.160781e+06   1.161542e+06  1.161542e+06
# mean   1.499908e+09       1.635188e+00   2.861034e+01  3.017188e+02
# std    2.879193e+08       3.564454e+00   3.085018e+01  2.921470e+03
# min    1.003000e+09       1.000000e+00   1.000000e+00  1.100000e+01
# 25%    1.245877e+09       1.000000e+00   9.000000e+00  5.600000e+01
# 50%    1.497996e+09       1.000000e+00   1.800000e+01  1.430000e+02
# 75%    1.750301e+09       1.000000e+00   3.800000e+01  3.100000e+02
# max    1.993000e+09       9.900000e+01   7.910000e+02  1.767363e+06
#
#           Tot_Srvcs  Tot_Sbmtd_Chrg  Tot_Mdcr_Alowd_Amt  Tot_Mdcr_Pymt_Amt  \
# count  1.161542e+06    1.161542e+06        1.161542e+06       1.161542e+06
# mean   2.545648e+03    3.313148e+05        1.065768e+05       8.389603e+04
# std    4.731484e+04    2.624510e+06        6.217279e+05       5.727565e+05
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1161542 entries, 0 to 1161541
# Data columns (total 73 columns):
#  #   Column                         Non-Null Count    Dtype
# ---  ------                         --------------    -----
#  0   Rndrng_NPI                     1161542 non-null  int64
#  1   Rndrng_Prvdr_Last_Org_Name     1161542 non-null  object
#  2   Rndrng_Prvdr_First_Name        1100800 non-null  object
#  3   Rndrng_Prvdr_MI                753740 non-null   object
#  4   Rndrng_Prvdr_Crdntls           1029252 non-null  object
#  5   Rndrng_Prvdr_Gndr              1100800 non-null  object
#  6   Rndrng_Prvdr_Ent_Cd            1161542 non-null  object
#  7   Rndrng_Prvdr_St1               1161542 non-null  object
#  8   Rndrng_Prvdr_St2               321038 non-null   object
#  9   Rndrng_Prvdr_City              1161542 non-null  object
#  10  Rndrng_Prvdr_State_Abrvtn      1161542 non-null  object
#  11  Rndrng_Prvdr_State_FIPS        1161537 non-null  object
# ...

# %%
'Rndrng_NPI',
'Rndrng_Prvdr_Last_Org_Name',
'Rndrng_Prvdr_First_Name',
'Rndrng_Prvdr_MI',
'Rndrng_Prvdr_Crdntls',
'Rndrng_Prvdr_Gndr',
'Rndrng_Prvdr_Ent_Cd',
'Rndrng_Prvdr_St1',
'Rndrng_Prvdr_St2',
'Rndrng_Prvdr_City',
'Rndrng_Prvdr_State_Abrvtn',
'Rndrng_Prvdr_State_FIPS',
'Rndrng_Prvdr_Zip5',
'Rndrng_Prvdr_RUCA',
'Rndrng_Prvdr_RUCA_Desc',
'Rndrng_Prvdr_Cntry',
'Rndrng_Prvdr_Type',
'Rndrng_Prvdr_Mdcr_Prtcptg_Ind'

# %%
'Tot_HCPCS_Cds',
'Tot_Benes',
'Tot_Srvcs',
'Tot_Sbmtd_Chrg',
'Tot_Mdcr_Alowd_Amt',
'Tot_Mdcr_Pymt_Amt',
'Tot_Mdcr_Stdzd_Amt',
'Drug_Tot_HCPCS_Cds',
'Drug_Tot_Benes',
'Drug_Tot_Srvcs',
'Drug_Mdcr_Alowd_Amt',
'Drug_Mdcr_Pymt_Amt',
'Drug_Mdcr_Stdzd_Amt',
'Med_Tot_HCPCS_Cds',
'Med_Tot_Benes',
'Med_Tot_Srvcs',
'Med_Mdcr_Alowd_Amt',
'Med_Mdcr_Pymt_Amt',
'Med_Mdcr_Stdzd_Amt'
